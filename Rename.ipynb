# %%
from google.colab import drive
from google.colab import files
import os

drive.mount('/content/drive')                                                       ##customize drive path 
dataset_path = "/content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/"
list_dir = [str(os.path.join(dataset_path, dir)) for dir in os.listdir(dataset_path)]
class_images = ['normal', 'benign', 'malignant']
all_path = []
for class_image in class_images:
  for dir in list_dir:
    all_path.append(os.path.join(dir, class_image))

for path in all_path:
  print(path + "***" + str(len(os.listdir(path))))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/val/normal***54
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/test/normal***53
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/train/normal***26
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/val/benign***175
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/test/benign***175
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/train/benign***87
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/val/malignant***84
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/test/malignant***84
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/train/malignant***42

# %%
for path in all_path:
  i = 1
  ldseg = os.listdir(path)
  for filename in ldseg:
    newname = filename.split(' ')[0] + '_(' + str(i) + ').png'
    src = os.path.join(path, filename)
    newname = os.path.join(path, newname)
    os.rename(src, newname)
    i += 1

for path in all_path:
  print(path + "***" + str(len(os.listdir(path))))
# Out:
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/val/normal***54
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/test/normal***53
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/train/normal***26
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/val/benign***175
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/test/benign***175
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/train/benign***87
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/val/malignant***84
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/test/malignant***84
# /content/drive/My Drive/Colab Notebooks/Breast cancer/dataset/train/malignant***42
